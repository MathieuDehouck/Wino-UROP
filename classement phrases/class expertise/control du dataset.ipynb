# %%
import pandas as pd

# %%
df = pd.read_csv("phrases_annotees.csv")
pd.set_option('display.max_colwidth', None)

# %%
df = df[df['label'] != -1]

# %%
df
# Out:
#                                    qID  \
# 3     3Y3CZJSZ9KRTC691AD0DJY5RDO45RP-1
# 5     3CMIQF80GNOPJ9UF2HLI6E9M8HA6Q1-1
# 11    3UZUVSO3P7T2B9P2G6XZ1THUFBBEMB-1
# 12    3KVQ0UJWPXJYK2QN97AJ6XD856EW5K-1
# 16    3PGQRAZX04YI9YI5K2HFC3WPJUFYSI-1
# ...                                ...
# 1189  3HXCEECSQMR0GL5CVWZNGY5JCT8ZY6-1
# 1192  3E24UO25Q141SMG6725E972VO12O67-1
# 1202  38XPGNCKHVEI3JLPPQYD71CPO1CV4A-1
# 1204  3QTFNPMJC8WLYB058S2CRGVK16WZNE-1
# 1205  3NKW03WTLM5NDO9LTZYM488Z13RWQP-1
#
#                                                                                                                                                             phrase  \
# 3                    Sue traditionally donated old clothes to her favorite charity but in recent years has just written them checks as the _ were better received.
# 5                                                               Mary had a better body and was more of a showoff than Emily. _ loves wearing bikinis to the beach.
# ...
