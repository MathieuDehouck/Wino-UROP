# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("classe_expertise_entier.csv")
df = df.drop('Unnamed: 0', axis=1)

df
# Out:
#                                     qID  \
# 0      3QHITW7OYO7Q6B6ISU2UMJB84ZLAQE-2
# 1      3QHITW7OYO7Q6B6ISU2UMJB84ZLAQE-1
# 2      3XWUWJ18TLO2DDRXF83QWLKRJ29UU4-1
# 3      3XWUWJ18TLO2DDRXF83QWLKRJ29UU4-2
# 4      3D5G8J4N5CI2K40F4RZLF9OG2CKVTH-2
# ...                                 ...
# 40393  3PKJ68EHDNUOUBAJ3ASD64MQ8GSJHJ-1
# 40394  3W1K7D6QSDVJX2B852X30LVRM6WZBL-1
# 40395  3W1K7D6QSDVJX2B852X30LVRM6WZBL-2
# 40396  3BO3NEOQM2VSJ2H6ZK9L5F8V75BAIT-1
# 40397  3BO3NEOQM2VSJ2H6ZK9L5F8V75BAIT-2
#
#                                                 sentence option1   option2  \
# 0      Ian volunteered to eat Dennis's menudo after a...     Ian    Dennis
# 1      Ian volunteered to eat Dennis's menudo after a...     Ian    Dennis
# 2      He never comes to my home, but I always go to ...    home     house
# 3      He never comes to my home, but I always go to ...    home     house
# 4      Kyle doesn't wear leg warmers to bed, while Lo...    Kyle     Logan
# ...

# %%
class_counts = df['classe'].value_counts()

plt.figure(figsize=(10, 6))
class_counts.plot(kind='bar', color='teal')

plt.title('Répartition des classes')
plt.xlabel('Classes')
plt.ylabel('Fréquence')
plt.xticks(rotation=0)
plt.grid(axis='y', alpha=0.3)


plt.tight_layout()
plt.show()

# %%
class_counts
# Out:
# classe
# autre          23751
# expertise       8395
# incertitude     8252
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))

plt.hist(df['probabilite_expertise'], 
         bins=50, 
         color='teal', 
         edgecolor='black', 
         alpha=0.7)

plt.title('Distribution des probabilités de "expertise"')
plt.xlabel('Probabilité')
plt.ylabel('Fréquence')
plt.grid(axis='y', alpha=0.4)
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %%
# Top 10 des probabilités les plus élevées
top10 = df.nlargest(10, 'probabilite_expertise').assign(position='Top')

# Top 10 des probabilités les plus basses
bottom10 = df.nsmallest(10, 'probabilite_expertise').assign(position='Bottom')

# %%
pd.set_option('display.max_colwidth', None)
top10
# Out:
#                                     qID  \
# 16346  3EHVO81VN7ZWTJTMXJY7U2EC24XH1Z-2
# 32797  36BTXXLZ2XMQAC48G6T364NL1NS4RZ-2
# 16347  3EHVO81VN7ZWTJTMXJY7U2EC24XH1Z-1
# 3002   3ZQA3IO31BPRRBG2HYHXMDN5QOY1OJ-1
# 3003   3ZQA3IO31BPRRBG2HYHXMDN5QOY1OJ-2
# 22558  3XD2A6FGFP838XAXCQPZDM3X91O9SR-2
# 25294  32CAVSKPCENM4G0ZDKT6LJFU3UYU10-2
# 5670   3W31J70BASUSON5LZ3EOWSPNAHFKCA-2
# 29152  3IJ95K7NDXA6D56TY22NEBR6XLKNGT-1
# 11958  3S829FDFT4FN749DIG0OYQ3FFHRXDM-1
#
#                                                                                                            sentence  \
# 16346        Laura taught their skills to Jessica, because _ wanted to learn about all their accumulated knowledge.
# 32797                Erin offered to help Natalie build her new house, although _ possessed talent at construction.
# 16347         Laura taught their skills to Jessica, because _ wanted to pass along all their accumulated knowledge.
# ...

# %%
bottom10
# Out:
#                                     qID  \
# 20303  3AA88CN98P15RQ6QVVWDTJH6D2KKYZ-1
# 20276  3JYPJ2TAYI602QMB3X9X0FWP12DFPD-1
# 16981  3UXQ63NLAC0ZSDU4Q16US6KT7RIBLW-2
# 27927  3CRWSLD91MI3HP1YUICVY3ZGCQ1OMB-1
# 4378   34R0BODSP3DJXR3385SDCPUHNY35E9-2
# 16816  37SDSEDINBG308STUF41HPLDZWL184-2
# 1586   33K3E8REWY9BQ9DM18P8CYPE4PI8XD-2
# 28062  3J9UN9O9J56SD03UP0XSSABIBYO0J4-1
# 201    3YLPJ8OXXARA78QKP5ZVVM9A3A94X6-2
# 28938  36818Z1KV3BYZA0GUJQY9BIXZOPA3W-1
#
#                                                                                                             sentence  \
# 20303                            Bob spent more money on food than he did on the candy, because the _ was healthier.
# 20276                            The teenager used cream instead of oil on his acne. The _ was much more irritating.
# 16981   The couple wanted a wedding cake with fondant or buttercream.  They went with the _ because it was creamier.
# ...

# %%
df = df[df['classe'] == "incertitude"]
df
# Out:
#                                     qID  \
# 32     3M7OI89LVYMLP8KWXZKNM9K59J76CX-1
# 33     3M7OI89LVYMLP8KWXZKNM9K59J76CX-2
# 40     3THR0FZ95R7JB7JDU6BGYQKRCK0OLW-2
# 41     3THR0FZ95R7JB7JDU6BGYQKRCK0OLW-1
# 46     3TCFMTM8HEMDK4RXU0J0F0K2KZI21L-2
# ...                                 ...
# 40388  3Z8UJEJOC1RZOGPIMBOY5EVLHB339N-2
# 40389  3Z8UJEJOC1RZOGPIMBOY5EVLHB339N-1
# 40392  3PKJ68EHDNUOUBAJ3ASD64MQ8GSJHJ-2
# 40393  3PKJ68EHDNUOUBAJ3ASD64MQ8GSJHJ-1
# 40394  3W1K7D6QSDVJX2B852X30LVRM6WZBL-1
#
#                                                                                                                              sentence  \
# 32      I installed a new bird house outside above the ground, but had to prop it up higher away from my cat since the _ was too low.
# 33     I installed a new bird house outside above the ground, but had to prop it up higher away from my cat since the _ was too high.
# ...
