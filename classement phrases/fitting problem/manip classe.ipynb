# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("classe.csv")
df = df.drop('Unnamed: 0', axis=1)

df
# Out:
#                                     qID  \
# 0      3QHITW7OYO7Q6B6ISU2UMJB84ZLAQE-2
# 1      3QHITW7OYO7Q6B6ISU2UMJB84ZLAQE-1
# 2      3XWUWJ18TLO2DDRXF83QWLKRJ29UU4-1
# 3      3XWUWJ18TLO2DDRXF83QWLKRJ29UU4-2
# 4      3D5G8J4N5CI2K40F4RZLF9OG2CKVTH-2
# ...                                 ...
# 40393  3PKJ68EHDNUOUBAJ3ASD64MQ8GSJHJ-1
# 40394  3W1K7D6QSDVJX2B852X30LVRM6WZBL-1
# 40395  3W1K7D6QSDVJX2B852X30LVRM6WZBL-2
# 40396  3BO3NEOQM2VSJ2H6ZK9L5F8V75BAIT-1
# 40397  3BO3NEOQM2VSJ2H6ZK9L5F8V75BAIT-2
#
#                                                 sentence option1   option2  \
# 0      Ian volunteered to eat Dennis's menudo after a...     Ian    Dennis
# 1      Ian volunteered to eat Dennis's menudo after a...     Ian    Dennis
# 2      He never comes to my home, but I always go to ...    home     house
# 3      He never comes to my home, but I always go to ...    home     house
# 4      Kyle doesn't wear leg warmers to bed, while Lo...    Kyle     Logan
# ...

# %%
class_counts = df['classe'].value_counts()

plt.figure(figsize=(10, 6))
class_counts.plot(kind='bar', color='teal')

plt.title('Répartition des classes')
plt.xlabel('Classes')
plt.ylabel('Fréquence')
plt.xticks(rotation=0)
plt.grid(axis='y', alpha=0.3)


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.hist(df['probabilite_contenance'], 
         bins=50, 
         color='teal', 
         edgecolor='black', 
         alpha=0.7)

plt.title('Distribution des probabilités de "contenance"')
plt.xlabel('Probabilité')
plt.ylabel('Fréquence')
plt.grid(axis='y', alpha=0.4)
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %%
# Top 10 des probabilités les plus élevées
top10 = df.nlargest(10, 'probabilite_contenance').assign(position='Top')

# Top 10 des probabilités les plus basses
bottom10 = df.nsmallest(10, 'probabilite_contenance').assign(position='Bottom')

# %%
pd.set_option('display.max_colwidth', None)
top10
# Out:
#                                     qID  \
# 13121  37M4O367VLWH9FVGP3GWPXZQX0M5MR-1
# 15532  3UZUVSO3P99H5YO9049ZTR53ATLEM1-1
# 22419  3XABXM4AJ13CNND3VWIGQS5DJQBQ8F-2
# 38404  3SA4EMRVJXGOZB6SKD2CP6XTJND0P0-2
# 6724   36JW4WBR06I8P9ONKK1SR6UYFBMFHR-2
# 13120  37M4O367VLWH9FVGP3GWPXZQX0M5MR-2
# 38405  3SA4EMRVJXGOZB6SKD2CP6XTJND0P0-1
# 22418  3XABXM4AJ13CNND3VWIGQS5DJQBQ8F-1
# 3092   368IUKXGA7MJDMS7M2ITY77LY086P4-1
# 27168  37SOB9Z0SSVFVTRKRAFOIPY8TZSL3R-1
#
#                                                                                                                        sentence  \
# 13121                                               The old texts will not fit onto the screens because the _ are way too long.
# 15532                               I transferred my new photos from the memory card into the hard drive until the _ was empty.
# 22419                                                 The woman tried to put the books on the couches but the _ were too large.
# ...

# %%
bottom10
# Out:
#                                     qID  \
# 26756  3R0WOCG21M7GWBGBTDD1MLG3SR1UDQ-2
# 26757  3R0WOCG21M7GWBGBTDD1MLG3SR1UDQ-1
# 36188  3OND0WXMHWDGJVORP9HM9O9Y3BOHEU-1
# 27823  3ECKRY5B1QUEQLQ7REDKUABVMARZIH-2
# 39800  3QMELQS6Y59PVA9FFWAIB4JR9MY6RV-1
# 5730   33IXYHIZB7WRYUKGQMQFEIR42KSE2M-1
# 40297  335VBRURDJYN4P68RXTUW7BAFISE9C-2
# 5731   33IXYHIZB7WRYUKGQMQFEIR42KSE2M-2
# 35075  3KLL7H3EGFFCFV9K4XIW1QLSRYRHVR-1
# 38965  3LN3BXKGC29BUOEEA15A2SS6LBEGWB-2
#
#                                                                                                                                              sentence  \
# 26756                          Donald had light skin that would blister in the sun but Christopher didn't, therefore _ didn't need a high SPF lotion.
# 26757                               Donald had light skin that would blister in the sun but Christopher didn't, therefore _ needed a high SPF lotion.
# ...
