# %%
import pandas as pd

# %%
df = pd.read_csv("phrases_annotees.csv")
pd.set_option('display.max_colwidth', None)

# %%
df = df[df['label'] != -1]

# %%
df
# Out:
#                                    qID  \
# 0     3QHITW7OYO7Q6B6ISU2UMJB84ZLAQE-1
# 1     3NRZ1LDP7W4677DB493437C7D3WZP2-1
# 7     3MZ3TAMYTLL5OU4GHXJ7879WIBGRIT-1
# 9     3PIOQ99R7YKPIN7OI7R4IQSX6RPUNM-1
# 10    30Y6N4AHYPUOGJOUPJIWHATJQ9LDRW-1
# ...                                ...
# 1719  329E6HTMSYGJ5C89Q8FNVN92U0L3KH-1
# 1721  3YCT0L9OMONOXZERD084VNYHEQ4SN8-1
# 1723  3SSN80MU8E2VLAFNAXMB23Y5ZM5KXV-1
# 1725  3V0TR1NRVCGYBVIREV7HBEYB1IDA44-1
# 1731  3ZCC2DXSD720BVV7ZAX42RWHBK8YYT-1
#
#                                                                                                                        phrase  \
# 0                      Ian volunteered to eat Dennis's menudo after already having a bowl because _ enjoyed eating intestine.
# 1                  I picked up a bag of peanuts and raisins for a snack. I wanted a sweeter snack out so I ate the _ for now.
# ...
